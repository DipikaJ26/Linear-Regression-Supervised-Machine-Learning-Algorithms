# %% [markdown]
# # Linear Regression #

# %%
# Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import Dips_stats as dp

# %%
# Importing the data

# %%
df=pd.read_csv(r"C:\Users\ADMIN\Downloads\Student_Performance.csv")

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Extracurricular Activities  \
# 0                                 1                           1
# 1                                 2                           0
# 2                                 2                           1
# 3                                 2                           1
# 4                                 5                           0
#
#    Performance Index
# 0                 91
# 1                 65
# 2                 45
# 3                 36
# 4                 66

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Sleep Hours                       10000 non-null  int64
#  3   Sample Question Papers Practiced  10000 non-null  int64
#  4   Extracurricular Activities        10000 non-null  int64
#  5   Performance Index                 10000 non-null  int64
# dtypes: int64(6)
# memory usage: 468.9 KB

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Extracurricular Activities  \
# count                      10000.000000                10000.000000
# mean                           4.583300                    0.494800
# std                            2.867348                    0.499998
# min                            0.000000                    0.000000
# 25%                            2.000000                    0.000000
# 50%                            5.000000                    0.000000
# ...

# %%
# Exploratory Data Analysis

# %%
col_name=['Hours Studied','Previous Scores','Sleep Hours','Sample Question Papers Practiced','Extracurricular Activities','Performance Index']
for i in col_name:
    print("***",i,"***","\n")
    std_obj=dp.cal_stats(df[i])
    std_obj.everything()
# Out:
# *** Hours Studied ***
#
# Total Sum: 49929
# Total Count: 10000
# Maximum Value: 9
# Minimum Value: 1
# Range: 8
# Mean: 4.9929
# Median: 5.0
# Mode: 1
# Variance: 6.703849589999982
# Standard Deviation: 2.589179327509005
# Skewness: -0.00421125228018963
# Kurtosis: -1.232481534219296
# Q1: 3.0
# Q3: 7.0
# IQR: 4.0
# Lower Whisker: -3.0
# Upper Whisker: 13.0
# Total Outliers Count: 0
# Variance: 6.704520042004183
# Standard Deviation: 2.589308796185612
# 1 Standard Deviation Range: (2.40 to 7.58) --> 55.60% of data
# 2 Standard Deviation Range: (-0.19 to 10.17) --> 100.00% of data
# 3 Standard Deviation Range: (-2.78 to 12.76) --> 100.00% of data
# 95% Confidence Interval: 4.94, 5.04
# 97% Confidence Interval: 4.94, 5.05
# 99% Confidence Interval: 4.93, 5.06
# Likely Does Not Follow Normal Distribution
# Detected Continuous Data
# ...

# %%
# Checking for null values

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Extracurricular Activities          0
# Performance Index                   0
# dtype: int64

# %%
# Train-Test-Split data

# %%
x= df.drop('Performance Index',axis=1)
y= df['Performance Index']

# %%
from sklearn.model_selection import train_test_split


x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000, 5)
# (2000, 5)
# (8000,)
# (2000,)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
df["predicted_values"] = lr.predict(df[['Hours Studied','Previous Scores','Sleep Hours','Sample Question Papers Practiced','Extracurricular Activities']])

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Extracurricular Activities  \
# 0                                 1                           1
# 1                                 2                           0
# 2                                 2                           1
# 3                                 2                           1
# 4                                 5                           0
#
#    Performance Index  predicted_values
# 0                 91         91.845663
# 1                 65         63.153396
# 2                 45         45.040958
# 3                 36         36.551970
# 4                 66         67.074197

# %%
y_pred = lr.predict(x_test)

# %%
lr.coef_
# Out:
# array([2.84696132, 1.01827038, 0.48318738, 0.19168683, 0.61653684])

# %%
lr.intercept_
# Out:
# -34.04874408702148

# %%
# Calculating the error value

# %%
# Sum of Squared Error --- sse 
sse=sum((y_test-y_pred)**2)
print("Sum of Squared Error : ",sse)

# Sum of Mean Squared Error-----mse
mse = sse/len(x_test)
print("Mean Squared Error : ",mse)

#Root Mean Squared Error-----rmse
rmse = np.sqrt(mse)
print("Root Mean Squared Error :",rmse)
# Out:
# Sum of Squared Error :  8589.566953711132
# Mean Squared Error :  4.2947834768555655
# Root Mean Squared Error : 2.0723859382015615

# %%
hr_study=float(input("How much hours you studied ?"))
prev_score=float(input("What is your previous score ?"))
sleep_hr=float(input("What is your sleep timing ?"))
que_pract=float(input("how much questions you practised ?"))
extracur=float(input("What are your extracuricular activity timings ?"))
user_input=np.array([hr_study,prev_score,sleep_hr,que_pract,extracur])
# Out:
# How much hours you studied ? 7
# What is your previous score ? 99
# What is your sleep timing ? 9
# how much questions you practised ? 1
# What are your extracuricular activity timings ? 1

# %%
# Prediction values---

# %%
Performance_index=lr.predict(user_input.reshape(1,-1))
print(f"Your performance index is between {round(y_pred[0])-2.0} to {round(y_pred[0])+2.0}")
# Out:
# Your performance index is between 40.0 to 44.0
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import joblib

# %%
joblib.dump(lr, "linear_regression_model 27-09-2025.pkl")
print("Model saved successfully!")
# Out:
# Model saved successfully!
